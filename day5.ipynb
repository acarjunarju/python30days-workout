# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **STRING**

# %%
 stg = "simplelearn"
 print(stg)
# Out:
# simplelearn

# %%
type(stg)
# Out:
# str

# %%
stg = """i am nagarjuna
welcome to my channel"""
print(stg)
# Out:
# i am nagarjuna
# welcome to my channel

# %%
len(stg)
# Out:
# 37

# %%
for i in stg:
  print(i)
# Out:
# i
#
# a
# m
#
# n
# a
# g
# a
# r
# j
# u
# n
# a
#
#
#
# w
# e
# l
# c
# o
# m
# e
#
# t
# o
#
# m
# y
#
# c
# h
# a
# n
# n
# e
# l

# %%
print(stg.upper())
# Out:
# I AM NAGARJUNA
# WELCOME TO MY CHANNEL

# %%
print(stg.lower())
# Out:
# i am nagarjuna
# welcome to my channel

# %%
 print(stg.split(","))
# Out:
# ['i am nagarjuna \nwelcome to my channel']

# %%
print(stg.replace("nagarjuna","arjun"))
# Out:
# i am arjun
# welcome to my channel

# %% [markdown]
# **concatnating**

# %%
stg1="good"
stg2="morning"
stg = stg1+stg2

# %%
stg
# Out:
# 'goodmorning'

# %% [markdown]
# SETS AND DICTIONARIES

# %%
d1 = {}
print(d1)
# Out:
# {}

# %%
type(d1)
# Out:
# dict

# %%
d2 = {1:"Welcome",2:"to",3:"python"}

# %%
print(d2)
# Out:
# {1: 'Welcome', 2: 'to', 3: 'python'}

# %%
d3 = {"name":"nagarjuna","age":21,"place":"Banglore"}
print(d3)
# Out:
# {'name': 'nagarjuna', 'age': 21, 'place': 'Banglore'}

# %%
d6 = {"name":{"first":"Naga","last":"arjun"} ,"age":21,"place":"Banglore",}
print(d6)
# Out:
# {'name': {'first': 'Naga', 'last': 'arjun'}, 'age': 21, 'place': 'Banglore'}

# %% [markdown]
# **ADDING ELEMENTS**

# %%
d = {}
d[0] = "welcome"

# %%
print(d)
# Out:
# {0: 'welcome'}

# %%
d[1] = "how","are", "you"
print(d)
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you')}
