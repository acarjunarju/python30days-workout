# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TUPLES**

# %%
emp=()
print(type(emp))
# Out:
# <class 'tuple'>

# %%
print(emp)
# Out:
# ()

# %%
city = "pune","banglore","Delhi","mumbai"
print(type(city))
# Out:
# <class 'tuple'>

# %%
print(city)
# Out:
# ('pune', 'banglore', 'Delhi', 'mumbai')

# %%
list1 = [1,2,3,4]
tuple1 = (1,2,3,4)
list1.append(5)
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(city[1])
# Out:
# banglore

# %%
print(city[-2])
# Out:
# Delhi

# %% [markdown]
# **concatnation**

# %%
num = (1,2,3,4)

# %%
print(city+num)
# Out:
# ('pune', 'banglore', 'Delhi', 'mumbai', 1, 2, 3, 4)

# %% [markdown]
# **NESTING**

# %%
nest=(city,num)
print(nest)
# Out:
# (('pune', 'banglore', 'Delhi', 'mumbai'), (1, 2, 3, 4))

# %% [markdown]
# REPETITION

# %%
rep = ("python")*5
print(rep)
# Out:
# pythonpythonpythonpythonpython

# %% [markdown]
# **SLICING**

# %%
num
# Out:
# (1, 2, 3, 4)

# %%
num[:2]
# Out:
# (1, 2)

# %%
num[::-1]
# Out:
# (4, 3, 2, 1)

# %% [markdown]
# **UNPACKING**

# %%
tuple("NAGARJUNA")
# Out:
# ('N', 'A', 'G', 'A', 'R', 'J', 'U', 'N', 'A')

# %%
num
# Out:
# (1, 2, 3, 4)

# %%
a,b,c,d= num
print(a,b,c,d)
# Out:
# 1 2 3 4

# %%
a,*b,c =num
print(a,b,c)
# Out:
# 1 [2, 3] 4

# %% [markdown]
# **DELETING A TUPLE**

# %%
tuple1=(1,2,3,4,5,6,7)
print(tuple1)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
del tuple1

# %%
print(tuole1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_800/3340939352.py in <cell line: 0>()
# ----> 1 print(tuole1)
#
# NameError: name 'tuole1' is not defined

# %% [markdown]
# **converting list to tuple**

# %%
lst = [1,2,3,4]
type(lst)
# Out:
# list

# %%
tpl = tuple(lst)
print(tpl)
# Out:
# (1, 2, 3, 4)

# %%
tpl = (4,3,2,5,3)
type(tpl)
# Out:
# tuple

# %%
lst = list(tpl)
print(type(lst))
# Out:
# <class 'list'>

# %% [markdown]
# NESTING TUPLES in a list

# %%
lst =[(1,2,3),(4,5,6)]
print(lst)
# Out:
# [(1, 2, 3), (4, 5, 6)]

# %%
lst.append(("apple","banana","orange"))
print(lst)
# Out:
# [(1, 2, 3), (4, 5, 6), ('apple', 'banana', 'orange'), ('apple', 'banana', 'orange')]

# %%
lst.remove((1,2,3))
print(lst)
# Out:
# [(4, 5, 6), ('apple', 'banana', 'orange'), ('apple', 'banana', 'orange')]
