# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world ")
# Out:
# hello world

# %%
name = input("enter your name ")
print("hlo",name)
# Out:
# enter your name nagarjuna
# hlo nagarjuna

# %%
x = 10
print(x)
# Out:
# 10

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 3.24
print(type(x))
# Out:
# <class 'float'>

# %%
x = "arjun"
print(type(x))
# Out:
# <class 'str'>

# %%
x = [14,67,9]
print(x)
# Out:
# [14, 67, 9]

# %%
type(x)
# Out:
# list

# %%
print(x[1])
# Out:
# 67

# %%
print(x[0])
# Out:
# 14

# %%
x[2] = 52

# %%
x
# Out:
# [14, 67, 52]

# %%
x = (12,21,32,15)
x
# Out:
# (12, 21, 32, 15)

# %%
type(x)
# Out:
# tuple
