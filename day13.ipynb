# %% [markdown]
# <a href="https://colab.research.google.com/github/acarjunarju/python30days-workout/blob/main/day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SCIPY**

# %%
from scipy import constants

# %%
print(constants.pi)
print(constants.c)
print(constants.h)
print(constants.N_A)
# Out:
# 3.141592653589793
# 299792458.0
# 6.62607015e-34
# 6.02214076e+23
